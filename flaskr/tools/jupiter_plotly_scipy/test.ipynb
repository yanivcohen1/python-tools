# %%
from platform import python_version
print(python_version())
# Out:
# 3.10.11

# %%
import ipykernel
ipykernel.__version__
# Out:
# '6.29.0'

# %%
import IPython
IPython.__version__
# Out:
# '8.20.0'

# %%
import platform
platform.system()
# Out:
# 'Windows'
