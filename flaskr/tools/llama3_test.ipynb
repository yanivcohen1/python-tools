# %%
# Example: reuse your existing OpenAI setup
from openai import OpenAI
from IPython.display import Markdown

# install moduls path: C:\Users\yaniv\.cache\lm-studio\models\LM Studio Community\
# start LM Studio
# select module
# start the server
# open url: http://localhost:1234/v1/models
# Point to the local server
client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")

my_msg = "write python code that get data from url"

completion = client.chat.completions.create(
    model="LM Studio Community/Meta-Llama-3-8B-Instruct-GGUF",
    messages=[
        {"role": "system", "content": "Always answer in rhymes."},
        {"role": "user", "content": my_msg},
    ],
    temperature=0.7,
)

Markdown(completion.choices[0].message.content)
# Out:
# Here is an example of how to use Python's `requests` library to fetch data from a URL:
# ```
# import requests
#
# # URL to fetch data from
# url = "https://www.example.com/data"
#
# # Send a GET request to the URL
# response = requests.get(url)
#
# # Check if the request was successful
# if response.status_code == 200:
#     # Get the content of the response (data)
#     data = response.content
#
#     # Decode the content as UTF-8 text
#     text_data = data.decode("utf-8")
#
#     # Print the data
#     print(text_data)
# else:
#     print(f"Failed to retrieve data from {url}. Status code: {response.status_code}")
# ```
# This code will send a GET request to the specified URL, and then print out the contents of the response. If the request is successful (status code 200), it will decode the content as UTF-8 text and print it. If the request fails, it will print an error message.
#
# Remember that this is just one way to fetch data from a URL in Python, and there are many other libraries and approaches you could use depending on your specific needs and requirements.
