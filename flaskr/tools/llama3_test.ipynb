# %%
# Example: reuse your existing OpenAI setup
from openai import OpenAI
from IPython.display import Markdown
import textwrap

# install moduls path: C:\Users\yaniv\.cache\lm-studio\models\LM Studio Community\
# start LM Studio url: https://lmstudio.ai/
# select module
# start the server
# open url: http://localhost:1234/v1/models
# see server log in real time on respones
# Point to the local server
client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")


def to_markdown(text):
    text = text.replace('•', '  *')
    return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

def sendServer(my_msg):
  completion = client.chat.completions.create(
    model="LM Studio Community/Meta-Llama-3-8B-Instruct-GGUF",
    messages=[
        {"role": "system", "content": ", if code in response add the code in markdown like this ```{program_language_name}"},
        {"role": "user", "content": my_msg},
    ],
    temperature=0.7,
  )

  return to_markdown(completion.choices[0].message.content)

# %%
my_msg = "What is the meaning of life in 2 points number it 1. and 2."
sendServer(my_msg)
# Out:
# > A profound question! While there may not be a definitive answer, here are two possible perspectives on the meaning of life:
# >
# > **1. Pursuing Happiness and Fulfillment**
# > The meaning of life can be found in the pursuit of happiness and fulfillment. This perspective suggests that our purpose is to live a life that brings us joy, contentment, and a sense of accomplishment. We should strive to cultivate positive relationships, pursue our passions, and find meaning through personal growth and self-improvement.
# >
# > **2. Leaving a Lasting Impact**
# > Another possible interpretation of the meaning of life is leaving a lasting impact on the world. This perspective emphasizes the importance of contributing positively to society, making a difference in the lives of others, and leaving behind a legacy that outlives us. It encourages individuals to use their unique talents, skills, and experiences to make a meaningful contribution to the world.
# >
# ...

# %%
sendServer("write in max 50 words python code that get url data")
# Out:
# > ```python
# > import requests
# > url = "https://www.example.com"
# > response = requests.get(url)
# > data = response.text
# > print(data)
# > ```
# >
# > This Python code sends a GET request to the specified URL, retrieves the HTML content, and prints it.

# %%
sendServer("write in max 50 words python code convert json to dict")
# Out:
# > Here is a Python code snippet that converts JSON to a dictionary:
# > ```python
# > import json
# >
# > json_string = '{"name": "John", "age": 30}'
# > data = json.loads(json_string)
# >
# > print(data)  # Output: {'name': 'John', 'age': 30}
# > ```
