# %%
# Example: reuse your existing OpenAI setup
from openai import OpenAI
from IPython.display import Markdown

# install moduls path: C:\Users\yaniv\.cache\lm-studio\models\LM Studio Community\
# start LM Studio
# select module
# start the server
# open url: http://localhost:1234/v1/models
# Point to the local server
client = OpenAI(base_url="http://localhost:1234/v1", api_key="lm-studio")

def sendServer(my_msg):
  completion = client.chat.completions.create(
    model="LM Studio Community/Meta-Llama-3-8B-Instruct-GGUF",
    messages=[
        # {"role": "system", "content": "Always answer in rhymes."},
        {"role": "user", "content": my_msg},
    ],
    temperature=0.7,
  )

  return Markdown(completion.choices[0].message.content)

# %%
my_msg = "What is the meaning of life in 2 points number it 1. and 2."
sendServer(my_msg)
# Out:
# A profound question! Here are two possible perspectives on the meaning of life:
#
# **1. Pursue happiness and fulfillment:** The meaning of life can be to find happiness, contentment, and a sense of fulfillment through one's experiences, relationships, and personal growth. This perspective emphasizes the importance of living in the present moment, cultivating positive emotions, and pursuing activities that bring joy and satisfaction.
#
# **2. Contribute positively to others and society:** Another perspective on the meaning of life is to make a positive impact on the world by contributing to the greater good. This might involve helping others, making a difference in one's community, or leaving a lasting legacy. This perspective highlights the importance of empathy, compassion, and service to others in finding purpose and significance.
#
# Of course, these are just two possible perspectives, and individuals may find their own unique meaning in life that is personal to them.

# %%
my_msg = "write python code that get data from url"
sendServer(my_msg)
# Out:
# Here is an example of how you can use Python to get data from a URL:
# ```
# import requests
#
# # Define the URL you want to fetch
# url = "https://www.example.com"
#
# # Send a GET request to the URL and save the response as a variable
# response = requests.get(url)
#
# # Check if the request was successful
# if response.status_code == 200:
#     # Get the content of the response (in this case, HTML)
#     data = response.content
#
#     # Print the data (you can also write it to a file or do something else with it)
#     print(data)
# else:
#     print("Failed to retrieve data from URL")
# ```
# This code uses the `requests` library, which is a popular and easy-to-use library for making HTTP requests in Python.
#
# Here's how you can use this code:
#
# 1. Replace `"https://www.example.com"` with the actual URL you want to fetch.
# 2. Run the code by saving it to a file (e.g., `get_data.py`) and then running it using Python (e.g., `python get_data.py`).
#
# The output will be the HTML content of the webpage at the specified URL.
#
# Note: Make sure you have the `requests` library installed. You can install it using pip:
# ```
# pip install requests
# ```
# Also, keep in mind that this is just a basic example, and depending on the complexity of the data you're trying to fetch, you may need to add additional error handling or processing steps.
#
# Alternatively, you can use other libraries such as `urllib` or `pycurl` to achieve similar results.
